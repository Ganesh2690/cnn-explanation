# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_theme(style="whitegrid")
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop

# %%
data = pd.read_csv('loan_data.csv')
data.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
data.shape
# Out:
# (9578, 14)

# %%
data.columns
# Out:
# Index(['credit.policy', 'purpose', 'int.rate', 'installment', 'log.annual.inc',
#        'dti', 'fico', 'days.with.cr.line', 'revol.bal', 'revol.util',
#        'inq.last.6mths', 'delinq.2yrs', 'pub.rec', 'not.fully.paid'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
data.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %% [markdown]
# ### 1.	Feature Transformation
#
# #### a.	Transform categorical values into numerical values (discrete)

# %%
d1 = data['purpose'].value_counts(normalize=True) * 100
d2 = data['purpose'].value_counts()
df=data
print(pd.concat([d1,d2],axis=1))
# Out:
#                       purpose  purpose
# debt_consolidation  41.313427     3957
# all_other           24.337022     2331
# credit_card         13.176028     1262
# home_improvement     6.567133      629
# small_business       6.462727      619
# major_purchase       4.562539      437
# educational          3.581123      343

# %%
df.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
# Convert 'purpose' (categorical variable) to numerical format using label encoding.
le = LabelEncoder()
df['purpose'] = le.fit_transform(df['purpose'])
df.purpose.value_counts()
# Out:
# 2    3957
# 0    2331
# 1    1262
# 4     629
# 6     619
# 5     437
# 3     343
# Name: purpose, dtype: int64

# %%
df.head()
# Out:
#    credit.policy  purpose  int.rate  installment  log.annual.inc    dti  fico  \
# 0              1        2    0.1189       829.10       11.350407  19.48   737
# 1              1        1    0.1071       228.22       11.082143  14.29   707
# 2              1        2    0.1357       366.86       10.373491  11.63   682
# 3              1        2    0.1008       162.34       11.350407   8.10   712
# 4              1        1    0.1426       102.92       11.299732  14.97   667
#
#    days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# 0        5639.958333      28854        52.1               0            0
# 1        2760.000000      33623        76.7               0            0
# 2        4710.000000       3511        25.6               1            0
# 3        2699.958333      33667        73.2               1            0
# 4        4066.000000       4740        39.5               0            1
#
#    pub.rec  not.fully.paid
# 0        0               0
# ...

# %%
df.describe()
# Out:
#        credit.policy      purpose     int.rate  installment  log.annual.inc  \
# count    9578.000000  9578.000000  9578.000000  9578.000000     9578.000000
# mean        0.804970     1.944038     0.122640   319.089413       10.932117
# std         0.396245     1.686881     0.026847   207.071301        0.614813
# min         0.000000     0.000000     0.060000    15.670000        7.547502
# 25%         1.000000     1.000000     0.103900   163.770000       10.558414
# 50%         1.000000     2.000000     0.122100   268.950000       10.928884
# 75%         1.000000     2.000000     0.140700   432.762500       11.291293
# max         1.000000     6.000000     0.216400   940.140000       14.528354
#
#                dti         fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean     12.606679   710.846314        4560.767197  1.691396e+04    46.799236
# ...

# %%
df.isna().sum()
# Out:
# credit.policy        0
# purpose              0
# int.rate             0
# installment          0
# log.annual.inc       0
# dti                  0
# fico                 0
# days.with.cr.line    0
# revol.bal            0
# revol.util           0
# inq.last.6mths       0
# delinq.2yrs          0
# pub.rec              0
# not.fully.paid       0
# dtype: int64

# %%
df.shape
# Out:
# (9578, 14)

# %%
# Create separate boxplots for each column for outliers
plt.figure(figsize=(8, 40))

for i, column in enumerate(df.columns):
    plt.subplot(len(df.columns), 1, i + 1)
    sns.boxplot(data=df[column])
    plt.title(column)

plt.show()

# %%
# df.corr()
corr = df.corr()
corr.style.background_gradient(cmap='copper')
# Out:
# <style type="text/css">
# #T_64bd8_row0_col0, #T_64bd8_row1_col1, #T_64bd8_row2_col2, #T_64bd8_row3_col3, #T_64bd8_row4_col4, #T_64bd8_row5_col5, #T_64bd8_row6_col6, #T_64bd8_row7_col7, #T_64bd8_row8_col8, #T_64bd8_row9_col9, #T_64bd8_row10_col10, #T_64bd8_row11_col11, #T_64bd8_row12_col12, #T_64bd8_row13_col13 {
#   background-color: #ffc77f;
#   color: #000000;
# }
# #T_64bd8_row0_col1 {
#   background-color: #170f09;
#   color: #f1f1f1;
# }
# #T_64bd8_row0_col2, #T_64bd8_row7_col5, #T_64bd8_row7_col11, #T_64bd8_row13_col0 {
#   background-color: #4d301f;
#   color: #f1f1f1;
# }
# #T_64bd8_row0_col3, #T_64bd8_row9_col7 {
#   background-color: #1b110b;
#   color: #f1f1f1;
# }
# #T_64bd8_row0_col4, #T_64bd8_row13_col7 {
#   background-color: #1a100a;
#   color: #f1f1f1;
# }
# #T_64bd8_row0_col5 {
#   background-color: #25170f;
#   color: #f1f1f1;
# }
# #T_64bd8_row0_col6 {
#   background-color: #c37b4f;
#   color: #f1f1f1;
# }
# #T_64bd8_row0_col7, #T_64bd8_row10_col11 {
# ...

# %%
sns.pairplot(df)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# #### As shown above there is no strong co relation between the columns/features in the datagram but column 	int.rate and fico column show strong negative correlation as shown below

# %%
corr = df[['int.rate', 'fico']].corr()
corr.style.background_gradient(cmap='copper')
# Out:
# <style type="text/css">
# #T_7e79b_row0_col0, #T_7e79b_row1_col1 {
#   background-color: #ffc77f;
#   color: #000000;
# }
# #T_7e79b_row0_col1, #T_7e79b_row1_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7e79b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e79b_level0_col0" class="col_heading level0 col0" >int.rate</th>
#       <th id="T_7e79b_level0_col1" class="col_heading level0 col1" >fico</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e79b_level0_row0" class="row_heading level0 row0" >int.rate</th>
#       <td id="T_7e79b_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_7e79b_row0_col1" class="data row0 col1" >-0.714821</td>
#     </tr>
#     <tr>
#       <th id="T_7e79b_level0_row1" class="row_heading level0 row1" >fico</th>
#       <td id="T_7e79b_row1_col0" class="data row1 col0" >-0.714821</td>
# ...

# %% [markdown]
# #### Hence will drop int.rate column

# %%
df = df.drop(['int.rate'], axis=1)

# %%
df.head()
# Out:
#    credit.policy  purpose  installment  log.annual.inc    dti  fico  \
# 0              1        2       829.10       11.350407  19.48   737
# 1              1        1       228.22       11.082143  14.29   707
# 2              1        2       366.86       10.373491  11.63   682
# 3              1        2       162.34       11.350407   8.10   712
# 4              1        1       102.92       11.299732  14.97   667
#
#    days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# 0        5639.958333      28854        52.1               0            0
# 1        2760.000000      33623        76.7               0            0
# 2        4710.000000       3511        25.6               1            0
# 3        2699.958333      33667        73.2               1            0
# 4        4066.000000       4740        39.5               0            1
#
#    pub.rec  not.fully.paid
# 0        0               0
# 1        0               0
# 2        0               0
# ...

# %%
df.columns
# Out:
# Index(['credit.policy', 'purpose', 'installment', 'log.annual.inc', 'dti',
#        'fico', 'days.with.cr.line', 'revol.bal', 'revol.util',
#        'inq.last.6mths', 'delinq.2yrs', 'pub.rec', 'not.fully.paid'],
#       dtype='object')

# %%
X = data[['purpose', 'installment', 'log.annual.inc', 'dti','fico', 'days.with.cr.line', 'revol.bal', 'revol.util',
       'inq.last.6mths', 'delinq.2yrs', 'pub.rec', 'not.fully.paid']]
y = data['credit.policy']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# %%
model = keras.Sequential( [ keras.layers.Dense(1024, input_shape=[X_train.shape[1]]), keras.layers.BatchNormalization(), keras.layers.Activation("relu"), keras.layers.Dense(512), keras.layers.BatchNormalization(), keras.layers.Activation("relu"), keras.layers.Dropout(0.3), keras.layers.Dense(256), keras.layers.BatchNormalization(), keras.layers.Activation("relu"), keras.layers.Dropout(0.2), keras.layers.Dense(1, activation="sigmoid"), ] )
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-48ca1d69e3f7> in <cell line: 1>()
# ----> 1 model = keras.Sequential( [ keras.layers.Dense(1024, input_shape=[X_train.shape[1]]), keras.layers.BatchNormalization(), keras.layers.Activation("relu"), keras.layers.Dense(512), keras.layers.BatchNormalization(), keras.layers.Activation("relu"), keras.layers.Dropout(0.3), keras.layers.Dense(256), keras.layers.BatchNormalization(), keras.layers.Activation("relu"), keras.layers.Dropou...
#       2 model.summary()
#
# NameError: name 'keras' is not defined
